# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from sklearn import cross_validation, metrics
from sklearn.grid_search import GridSearchCV

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

# %%
train=pd.read_csv("train_all1.csv")

# %%
train.sitesetID.describe()
# Out:
# count    2.615000e+06
# mean     2.469587e-01
# std      4.488328e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.000000e+00
# Name: sitesetID, dtype: float64

# %%
vn_list=[ 'creativeID', 'userID',
       'positionID', 'connectionType', 'telecomsOperator', 'adID',
       'camgaignID', 'advertiserID', 'appID', 'appPlatform', 'age',
       'gender', 'education', 'marriageStatus', 'haveBaby', 'residence',
       'sitesetID', 'positionType', 'appCategory',  'hour',
       'residence2', 'creativeID_age', 'creativeID_gender',
       'creativeID_education', 'creativeID_marriageStatus',
       'creativeID_haveBaby', 'creativeID_advertiserID',
       'creativeID_residence', 'creativeID_hour', 'sitesetID_positionType',
    'creativeID_residence2', 'creativeID_positionID',
       'creativeID_telecomsOperator', 'creativeID_sitesetID',
       'connectionType_residence', 'connectionType_residence2',
       'adID_advertiserID', 'adID_age', 'adID_gender', 'adID_education',
       'adID_marriageStatus', 'adID_haveBaby', 'age_gender',
       'age_gender_edu', 'camgaignID_age', 'camgaignID_gender',
       'camgaignID_education', 'camgaignID_marriageStatus',
       'camgaignID_haveBaby', 'camgaignID_age_gender_edu',
       'adID_age_gender_edu', 'creativeID_age_gender_edu', 'appID_age',
       'appID_gender', 'appID_education', 'appID_marriageStatus',
       'appID_haveBaby', 'appID_age_gender_edu', 'appID_appPlatform',
       'appPlatform_age', 'appPlatform_edu', 'appPlatform_age_gender_edu',
       'positionID_age', 'positionID_gender', 'positionID_education',
       'positionID_marriageStatus', 'positionID_haveBaby',
       'positionID_age_gender_edu', 'sitesetID_age', 'sitesetID_gender',
       'sitesetID_education', 'sitesetID_marriageStatus',
       'sitesetID_haveBaby', 'sitesetID_age_gender_edu']

# %%
vn_list_std=pd.DataFrame({'str':range(0,74),'std':range(0,74),'mean':range(0,74),'25%':range(0,74),'50%':range(0,74),'75%':range(0,74)})

# %%
qqqq=train.copy()

# %%
for i in xrange(11,12):
    vn=vn_list[i]
    filter_t = np.logical_and(qqqq.day.values > 16, qqqq.day.values <= 29)
    qqqq['_key1'] = qqqq[vn].astype('category').values.codes
    df_yt = qqqq.ix[filter_t, ['_key1', 'label']]
    grp1 = df_yt.groupby(['_key1'])
    sum1 = grp1['label'].aggregate(np.sum).astype(float)
    cnt1 = grp1['label'].aggregate(np.size)
    vn_list_std.loc[i,'str']=vn
    vn_list_std.loc[i,'std']=(sum1/cnt1).describe()[2]
    vn_list_std.loc[i,'25%']=(sum1/cnt1).describe()[4]
    vn_list_std.loc[i,'50%']=(sum1/cnt1).describe()[5]
    vn_list_std.loc[i,'75%']=(sum1/cnt1).describe()[6]
    vn_list_std.loc[i,'mean']=(sum1/cnt1).describe()[1]

# %%
sum1
# Out:
# _key1
# 0     7890.0
# 1    48294.0
# 2    30770.0
# Name: label, dtype: float64

# %%
cnt1
# Out:
# _key1
# 0      27517
# 1    1269763
# 2    1084337
# Name: label, dtype: int64

# %%
sum1/cnt1
# Out:
# _key1
# 0    0.286732
# 1    0.038034
# 2    0.028377
# Name: label, dtype: float64

# %%
np.std(sum1/cnt1)
# Out:
# 0.11957855242208329

# %%
vn_list_std.sort('std')
# Out:
#           25%        50%        75%       mean        std     str
# 0    0.000000   0.000000   0.000000   0.000000   0.000000       0
# 69  69.000000  69.000000  69.000000  69.000000  69.000000      69
# 70  70.000000  70.000000  70.000000  70.000000  70.000000      70
# 71  71.000000  71.000000  71.000000  71.000000  71.000000      71
# 72  72.000000  72.000000  72.000000  72.000000  72.000000      72
# 73  73.000000  73.000000  73.000000  73.000000  73.000000      73
#
# [74 rows x 6 columns]

# %%
def expctr(df,vn):
    vn_key = vn
    day1 = 16
    for day_v in xrange(17,30):
        filter_t = np.logical_and(df.day.values > day1, df.day.values <= day_v)
        t1 = df.ix[filter_t, :]
        filter_t2 = np.logical_and(t1.day.values != day_v, t1.day.values < 31)
        df['_key1'] = df[vn].astype('category').values.codes
        df_yt = df.ix[filter_t2, ['_key1', 'label']]
        grp1 = df_yt.groupby(['_key1'])
        sum1 = grp1['label'].aggregate(np.sum)
        cnt1 = grp1['label'].aggregate(np.size)
        v_codes = df.ix[df.day.values == day_v, '_key1']
        _sum = sum1[v_codes].values.astype(float)
        _cnt = cnt1[v_codes].values
        df.loc[df.day.values == day_v, 'cnttv_'+vn_key]=np.divide(_sum,_cnt)

del train['_key1']

# %%
for vn in vn_list:
     expctr(train,vn)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-111-75a138f03f4b> in <module>()
#       1 for vn in vn_list:
# ----> 2      expctr(train,vn)
#
# <ipython-input-98-38e0560cee01> in expctr(df, vn)
#       4     for day_v in xrange(22,30):
#       5         filter_t = np.logical_and(df.day.values > day1, df.day.values <= day_v)
# ----> 6         t1 = df.ix[filter_t, :]
#       7         filter_t2 = np.logical_and(t1.day.values != day_v, t1.day.values < 31)
#       8         df['_key1'] = df[vn].astype('category').values.codes
#
# F:\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#      74                 pass
#      75
# ---> 76             return self._getitem_tuple(key)
#      77         else:
#      78             return self._getitem_axis(key, axis=0)
#
# F:\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _getitem_tuple(self, tup)
#     798                 continue
#     799
# --> 800             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     801
#     802         return retval
#
# F:\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#     994                 raise ValueError('Cannot index with multidimensional key')
#     995
# --> 996             return self._getitem_iterable(key, axis=axis)
#     997         else:
#     998
#
# F:\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _getitem_iterable(self, key, axis)
#    1023             key = check_bool_indexer(labels, key)
#    1024             inds, = key.nonzero()
# -> 1025             return self.obj.take(inds, axis=axis, convert=False)
#    1026         else:
#    1027             if isinstance(key, Index):
#
# F:\Anaconda2\lib\site-packages\pandas\core\generic.pyc in take(self, indices, axis, convert, is_copy)
#    1626         new_data = self._data.take(indices,
#    1627                                    axis=self._get_block_manager_axis(axis),
# -> 1628                                    convert=True, verify=True)
#    1629         result = self._constructor(new_data).__finalize__(self)
#    1630
#
# F:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in take(self, indexer, axis, verify, convert)
#    3644         new_labels = self.axes[axis].take(indexer)
#    3645         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 3646                                     axis=axis, allow_dups=True)
#    3647
#    3648     def merge(self, other, lsuffix='', rsuffix=''):
#
# F:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3530             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    3531                 fill_value if fill_value is not None else blk.fill_value,))
# -> 3532                 for blk in self.blocks]
#    3533
#    3534         new_axes = list(self.axes)
#
# F:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#     982             fill_value = fill_tuple[0]
#     983             new_values = com.take_nd(values, indexer, axis=axis,
# --> 984                                      allow_fill=True, fill_value=fill_value)
#     985
#     986         if new_mgr_locs is None:
#
# F:\Anaconda2\lib\site-packages\pandas\core\common.pyc in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#     821             out = np.empty(out_shape, dtype=dtype, order='F')
#     822         else:
# --> 823             out = np.empty(out_shape, dtype=dtype)
#     824
#     825     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#
# MemoryError:

# %%
del train['_key1']
